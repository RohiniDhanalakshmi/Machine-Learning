# %%
import pandas as pd

# %%
dataset=pd.read_csv("50_Startups.csv")
dataset
# Out:
#      R &D spend  Administration  Marketing spend       State     Profit
# 0   165349.2162       136897.80         471784.10  new york   192261.83
# 1   162597.7000       151377.59         443898.53  califomia  191792.06
# 2   153441.5100       101145.55         407934.54    florida  191050.39
# 3   144372.4100       118671.85         383199.62  new york   182901.99
# 4   142107.3400        91391.77         366168.42    florida  166187.94
# 5   131876.9000        99814.71         362861.36  new york   156991.12
# 6   134615.4600       147198.87         127716.82  califomia  156122.51
# 7   130298.1300       145530.06         323876.68    florida  155752.60
# 8   120542.5200       148718.95         311613.29  new york   152211.77
# 9   123334.8800       108679.17         304981.62  califomia  149759.96
# 10  101913.0800       110594.11         229160.95    florida  146121.95
# 11  100671.9600        91790.61         249744.55  califomia  144259.40
# ...

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#      R &D spend  Administration  Marketing spend      Profit  State_florida  \
# 0   165349.2162       136897.80         471784.10  192261.83          False
# 1   162597.7000       151377.59         443898.53  191792.06          False
# 2   153441.5100       101145.55         407934.54  191050.39           True
# 3   144372.4100       118671.85         383199.62  182901.99          False
# 4   142107.3400        91391.77         366168.42  166187.94           True
# 5   131876.9000        99814.71         362861.36  156991.12          False
# 6   134615.4600       147198.87         127716.82  156122.51          False
# 7   130298.1300       145530.06         323876.68  155752.60           True
# 8   120542.5200       148718.95         311613.29  152211.77          False
# 9   123334.8800       108679.17         304981.62  149759.96          False
# 10  101913.0800       110594.11         229160.95  146121.95           True
# ...

# %%
dataset.columns
# Out:
# Index(['R &D spend', 'Administration', 'Marketing spend ', 'Profit',
#        'State_florida', 'State_new york '],
#       dtype='object')

# %%
independent=dataset[['R &D spend', 'Administration', 'Marketing spend ','State_florida', 'State_new york ']]
independent
# Out:
#      R &D spend  Administration  Marketing spend   State_florida  \
# 0   165349.2162       136897.80         471784.10          False
# 1   162597.7000       151377.59         443898.53          False
# 2   153441.5100       101145.55         407934.54           True
# 3   144372.4100       118671.85         383199.62          False
# 4   142107.3400        91391.77         366168.42           True
# 5   131876.9000        99814.71         362861.36          False
# 6   134615.4600       147198.87         127716.82          False
# 7   130298.1300       145530.06         323876.68           True
# 8   120542.5200       148718.95         311613.29          False
# 9   123334.8800       108679.17         304981.62          False
# 10  101913.0800       110594.11         229160.95           True
# 11  100671.9600        91790.61         249744.55          False
# 12   93863.7500       127320.38         249837.44           True
# ...

# %%
dependent=dataset[['Profit']]
dependent
# Out:
#        Profit
# 0   192261.83
# 1   191792.06
# 2   191050.39
# 3   182901.99
# 4   166187.94
# 5   156991.12
# 6   156122.51
# 7   155752.60
# 8   152211.77
# 9   149759.96
# 10  146121.95
# 11  144259.40
# 12  141585.52
# 13  134307.35
# 14  132602.65
# 15  129917.04
# 16  126992.93
# 17  125370.37
# 18  124266.90
# 19  122776.86
# 20  118474.03
# 21  111313.02
# 22  110352.25
# 23  108733.99
# 24  108552.04
# 25  107404.34
# 26  105733.54
# 27  105008.31
# 28  103282.38
# 29  101004.64
# 30   99937.59
# 31   97483.56
# 32   97427.84
# 33   96778.92
# 34   96712.80
# 35   96479.51
# 36   90708.19
# 37   89949.14
# 38   81229.06
# 39   81005.76
# 40   78239.91
# 41   77798.83
# 42   71498.49
# 43   69758.98
# 44   65200.33
# 45   64926.08
# 46   49490.75
# 47   42559.73
# 48   35673.52
# 49   14681.40

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor(criterion="log_loss")
regressor.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[9], line 3
#       1 from sklearn.ensemble import RandomForestRegressor
#       2 regressor=RandomForestRegressor(criterion="log_loss")
# ----> 3 regressor.fit(X_train,y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1467, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1462 partial_fit_and_fitted = (
#    1463     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1464 )
#    1466 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
#    1474     return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
y_pred=regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2score=r2_score(y_pred,y_test)
r2score

# %%
import pickle
filename="finale_model_randomforest.sav"

# %%
pickle.dump(regressor,open(filename,"wb"))

# %%
load_model=pickle.load(open("finale_model_randomforest.sav","rb"))
result=load_model.predict([[9541236,15485486,2648512,0,1]])
result
